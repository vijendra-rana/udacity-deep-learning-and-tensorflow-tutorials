# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
#testing
words[:10]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
[reverse_dictionary[i] for i in data[:10]] #data is stored in hashed form
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'term', 'originated', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.392759
# Nearest to a: forceful, proverb, pett, vignette, hairpin, cognates, confederacy, erin,
# Nearest to only: waylon, board, nod, supervillain, hinayana, reverting, rot, searching,
# Nearest to can: northrop, raf, mixolydian, scorsese, fluctuation, charley, cosmonaut, gothic,
# Nearest to while: pounding, bios, dislodge, alleviate, hab, agnosticism, derby, bahrain,
# Nearest to zero: pm, deadpan, cimmerian, hulls, forget, confirming, unsuitable, freight,
# Nearest to so: hyphae, challenging, fyodorovna, bradbury, prayers, abies, inquiring, distinctions,
# Nearest to to: pacheco, center, pumped, trillion, extrapolated, screename, cranston, adlai,
# Nearest to have: illustrating, portmanteaus, bestseller, xm, psychological, cal, westcott, sprout,
# Nearest to called: tongues, nederland, aedh, matsushita, assyrian, grocery, counterexample, convinced,
# Nearest to war: answering, lms, boiler, friendships, lightsaber, banchan, prophylactic, plummer,
# Nearest to will: application, hampshire, watchtower, suppressing, sanctuaries, biased, bouldering, quinlan,
# Nearest to use: yukon, alhazred, blitz, breathes, origin, punish, eurasia, uncontroversial,
# Nearest to not: sixties, explore, nonaligned, flavian, dictating, recovery, class, weston,
# Nearest to no: reestablished, meteorological, kumasi, obstacle, refresh, instruct, polymers, northrop,
# Nearest to some: bin, pedagogue, roux, giza, hickok, norsk, fronts, chih,
# Nearest to also: ange, hezekiah, redshifted, quipped, mg, napster, pioneer, traced,
# Average loss at step 2000: 4.359454
# Average loss at step 4000: 3.865371
# Average loss at step 6000: 3.790231
# Average loss at step 8000: 3.693263
# Average loss at step 10000: 3.616626
# Nearest to a: the, neburg, rico, austria, flourished, this, triphosphate, his,
# Nearest to only: clear, supervillain, board, stanislavski, asclepius, padded, malayalam, semantic,
# Nearest to can: should, would, could, might, may, must, will, lisbon,
# Nearest to while: alleviate, pounding, predecessors, agnosticism, hab, ads, infoplease, glitch,
# Nearest to zero: eight, six, seven, five, nine, four, three, two,
# Nearest to so: fyodorovna, cumings, bradbury, zapu, prayers, watt, hyphae, distinctions,
# Nearest to to: pacheco, not, affleck, would, pumped, interact, radio, curl,
# Nearest to have: be, has, had, are, were, galveston, inoculation, contemplation,
# Nearest to called: tongues, madhya, aedh, skills, administratively, welcomes, whispering, carcass,
# Nearest to war: lms, answering, cascading, hermetical, boiler, east, ringworld, supplying,
# Nearest to will: may, would, might, can, reject, application, deltas, suppressing,
# Nearest to use: yukon, eurasian, origin, asclepius, bacillus, blitz, oise, do,
# Nearest to not: it, never, to, mapped, display, they, casually, clique,
# Nearest to no: meteorological, steroid, rico, disciplines, broadcast, much, clung, adm,
# Nearest to some: many, outstripped, their, connery, lsi, conjugate, several, fermented,
# Nearest to also: which, sometimes, redshifted, diplomats, she, it, bodyline, inherent,
# Average loss at step 12000: 3.606516
# Average loss at step 14000: 3.575913
# Average loss at step 16000: 3.403935
# Average loss at step 18000: 3.457410
# Average loss at step 20000: 3.539854
# Nearest to a: the, another, this, sauce, yorkers, counsellor, pimlico, conformations,
# Nearest to only: clear, afternoon, engulfed, cyclones, moonlight, indicated, boomed, dinah,
# Nearest to can: would, should, may, could, will, must, might, to,
# Nearest to while: predecessors, pounding, agnosticism, sheol, although, alleviate, for, were,
# Nearest to zero: five, seven, six, four, nine, eight, three, two,
# Nearest to so: zapu, cumings, bradbury, debates, watt, nanyang, hoare, forges,
# Nearest to to: not, will, can, would, affleck, may, pacheco, could,
# Nearest to have: had, has, were, are, be, galveston, inoculation, shipwrecks,
# Nearest to called: aedh, whispering, madhya, tongues, motors, welcomes, wrist, postmodern,
# Nearest to war: lms, schala, answering, east, cascading, hermetical, ringworld, boiler,
# Nearest to will: would, can, may, might, must, should, to, reject,
# Nearest to use: yukon, origin, eurasian, bacillus, asclepius, rgensen, do, way,
# Nearest to not: never, to, it, mapped, they, also, usually, this,
# Nearest to no: rico, meteorological, interchanged, issachar, much, departments, andropov, disciplines,
# Nearest to some: many, several, these, their, other, most, all, its,
# Nearest to also: which, sometimes, still, now, generally, often, not, then,
# Average loss at step 22000: 3.507735
# Average loss at step 24000: 3.491074
# Average loss at step 26000: 3.484258
# Average loss at step 28000: 3.481850
# Average loss at step 30000: 3.501887
# Nearest to a: the, another, any, pimlico, ruminants, tear, yorkers, rico,
# Nearest to only: peninsular, clear, still, tenzin, kish, postmodernist, engulfed, outright,
# Nearest to can: may, would, could, will, should, must, might, cannot,
# Nearest to while: although, but, sheol, aho, cumberland, until, agnosticism, were,
# Nearest to zero: five, four, eight, three, seven, six, nine, two,
# Nearest to so: hoare, bradbury, forges, augusto, very, kata, thus, weathered,
# Nearest to to: would, can, will, pacheco, affleck, may, unseen, must,
# Nearest to have: had, has, were, are, be, include, galveston, having,
# Nearest to called: motors, postmodern, tongues, whispering, welcomes, thracian, carcass, madhya,
# Nearest to war: lms, cascading, schala, ringworld, hermetical, answering, specifications, winsor,
# Nearest to will: can, would, may, might, must, could, should, to,
# Nearest to use: origin, yukon, bacillus, liquid, omnivorous, asclepius, way, eurasian,
# Nearest to not: they, never, still, ing, warrington, clique, mapped, worthless,
# Nearest to no: any, issachar, meteorological, interchanged, rico, retro, andropov, little,
# Nearest to some: many, several, these, all, their, other, most, any,
# Nearest to also: sometimes, often, still, now, which, generally, badajoz, there,
# Average loss at step 32000: 3.501617
# Average loss at step 34000: 3.493810
# Average loss at step 36000: 3.454088
# Average loss at step 38000: 3.301276
# Average loss at step 40000: 3.427143
# Nearest to a: any, anaximenes, daewoo, another, kerry, the, or, triphosphate,
# Nearest to only: not, kish, still, tenzin, braddock, peninsular, screenplays, never,
# Nearest to can: could, will, may, would, should, must, might, cannot,
# Nearest to while: although, when, but, were, if, sheol, however, are,
# Nearest to zero: seven, five, nine, eight, six, two, three, metres,
# Nearest to so: thus, bradbury, weathered, zapu, hoare, very, debates, disseminated,
# Nearest to to: may, must, can, will, buber, affleck, flagellate, prefrontal,
# Nearest to have: had, has, were, are, be, include, cotswolds, galveston,
# Nearest to called: whispering, postmodern, laotian, begs, provably, convinced, referred, motors,
# Nearest to war: lms, answering, specifications, succeeded, hardened, bdsm, cusp, boomer,
# Nearest to will: can, would, may, must, could, should, might, where,
# Nearest to use: origin, lands, asclepius, yukon, way, bachelors, make, omnivorous,
# Nearest to not: still, never, it, they, clique, always, warrington, usually,
# Nearest to no: any, retro, issachar, meteorological, ramon, afer, underscored, melcher,
# Nearest to some: many, these, several, any, most, certain, those, their,
# Nearest to also: sometimes, often, still, which, generally, never, now, typically,
# Average loss at step 42000: 3.434685
# Average loss at step 44000: 3.449535
# Average loss at step 46000: 3.449177
# Average loss at step 48000: 3.355909
# Average loss at step 50000: 3.380553
# Nearest to a: another, daewoo, any, the, triphosphate, cmd, pimlico, savoy,
# Nearest to only: never, still, also, tenzin, afternoon, first, adept, euro,
# Nearest to can: could, will, may, would, should, must, might, cannot,
# Nearest to while: although, but, when, after, sheol, however, for, predecessors,
# Nearest to zero: seven, five, six, eight, four, three, two, nine,
# Nearest to so: thus, malory, disobeyed, bradbury, metalloid, furthering, zapu, kata,
# Nearest to to: would, could, disaccharides, will, should, may, can, morbid,
# Nearest to have: had, has, were, be, are, having, include, prior,
# Nearest to called: referred, motors, known, laotian, begs, postmodern, used, named,
# Nearest to war: lms, cusp, reproducible, specifications, arrows, succeeded, imagine, hermetical,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to use: origin, lands, asclepius, omnivorous, bachelors, feature, bulfinch, purpose,
# Nearest to not: never, still, usually, clique, now, they, mapped, warrington,
# Nearest to no: any, little, issachar, stroustrup, afer, melcher, retro, glycemic,
# Nearest to some: many, several, these, most, any, both, those, other,
# Nearest to also: often, still, which, now, sometimes, generally, redshifted, typically,
# Average loss at step 52000: 3.432352
# Average loss at step 54000: 3.426392
# Average loss at step 56000: 3.436858
# Average loss at step 58000: 3.396091
# Average loss at step 60000: 3.391960
# Nearest to a: another, any, the, every, interceptions, prostaglandins, no, shahi,
# Nearest to only: still, usually, first, contorted, not, also, inappropriately, permanent,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to while: although, when, before, after, though, sheol, if, were,
# Nearest to zero: five, four, seven, six, eight, three, two, nine,
# Nearest to so: if, thus, too, disobeyed, zapu, malory, hoare, kata,
# Nearest to to: pacheco, affleck, would, rejuvenation, for, will, may, criticizing,
# Nearest to have: has, had, include, are, were, be, having, accept,
# Nearest to called: used, referred, begs, considered, known, nos, named, postmodern,
# Nearest to war: lms, cusp, reproducible, arrows, imagine, paving, succeeded, specifications,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to use: lands, bachelors, purpose, most, demand, belief, way, asclepius,
# Nearest to not: still, never, usually, now, warrington, mapped, clique, they,
# Nearest to no: any, issachar, little, meteorological, retro, taller, a, theravada,
# Nearest to some: many, several, these, most, any, all, certain, this,
# Nearest to also: now, still, often, sometimes, never, generally, there, typically,
# Average loss at step 62000: 3.238262
# Average loss at step 64000: 3.254391
# Average loss at step 66000: 3.406012
# Average loss at step 68000: 3.395493
# Average loss at step 70000: 3.357704
# Nearest to a: the, another, any, daewoo, nye, shahi, or, each,
# Nearest to only: still, clear, gundam, last, usually, haus, never, villainous,
# Nearest to can: may, could, would, will, should, might, must, cannot,
# Nearest to while: although, when, however, though, are, before, if, including,
# Nearest to zero: five, six, eight, four, seven, three, two, nine,
# Nearest to so: thus, too, if, zapu, disobeyed, debates, kata, malory,
# Nearest to to: will, must, can, would, should, may, could, buber,
# Nearest to have: had, has, include, were, be, are, having, alters,
# Nearest to called: referred, considered, used, named, motors, characterized, magen, grocery,
# Nearest to war: lms, cusp, hardened, imagine, preservatives, arrows, paving, specifications,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to use: purpose, bachelors, belief, do, lands, demand, asclepius, most,
# Nearest to not: never, still, now, usually, always, actually, warrington, mapped,
# Nearest to no: any, little, retro, issachar, microbial, meteorological, alberoni, pki,
# Nearest to some: many, several, these, all, any, various, most, those,
# Nearest to also: still, now, often, never, sometimes, which, generally, usually,
# Average loss at step 72000: 3.371361
# Average loss at step 74000: 3.348832
# Average loss at step 76000: 3.311524
# Average loss at step 78000: 3.353200
# Average loss at step 80000: 3.380083
# Nearest to a: another, savoy, the, daewoo, azul, every, disguised, plekhanov,
# Nearest to only: motive, neither, villainous, braddock, send, interchanged, jotham, therefore,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to while: although, when, though, however, before, or, including, after,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to so: thus, too, if, zapu, before, debates, hoare, disobeyed,
# Nearest to to: disaccharides, will, buber, flagellate, must, would, should, pacheco,
# Nearest to have: had, has, include, be, are, were, having, alters,
# Nearest to called: referred, used, known, considered, named, characterized, designed, near,
# Nearest to war: cusp, lms, arrows, contae, paving, imagine, munitions, sheppard,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to use: because, bachelors, demand, attract, way, mindset, reprimanded, lands,
# Nearest to not: still, never, always, now, usually, warrington, actually, generally,
# Nearest to no: little, any, holbein, issachar, watchmen, glycemic, amman, butte,
# Nearest to some: many, several, various, these, any, most, both, certain,
# Nearest to also: often, now, sometimes, still, never, which, generally, typically,
# Average loss at step 82000: 3.409093
# Average loss at step 84000: 3.408714
# Average loss at step 86000: 3.392376
# Average loss at step 88000: 3.354408
# Average loss at step 90000: 3.366497
# Nearest to a: another, any, every, the, daewoo, tear, savoy, shahi,
# Nearest to only: neither, not, therefore, alternated, dayan, best, histology, directv,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to while: although, when, though, before, after, but, and, until,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to so: thus, too, malory, duels, documentary, zapu, debates, if,
# Nearest to to: would, pacheco, must, criticizing, buber, disaccharides, regum, will,
# Nearest to have: had, has, were, having, include, are, be, prior,
# Nearest to called: referred, used, considered, known, characterized, named, designed, magen,
# Nearest to war: anatomy, lms, arrows, cusp, imagine, sheppard, campaign, wilton,
# Nearest to will: would, can, must, could, should, may, might, cannot,
# Nearest to use: because, way, demand, furioso, mindset, lands, omnivorous, purpose,
# Nearest to not: never, only, nor, still, actually, they, warrington, mapped,
# Nearest to no: little, any, gw, achieved, microbial, alberoni, glycemic, retro,
# Nearest to some: many, several, these, any, both, all, certain, various,
# Nearest to also: often, sometimes, still, now, which, generally, never, usually,
# Average loss at step 92000: 3.395012
# Average loss at step 94000: 3.251301
# Average loss at step 96000: 3.357154
# Average loss at step 98000: 3.244667
# Average loss at step 100000: 3.359244
# Nearest to a: the, another, any, shahi, daewoo, cytosine, tear, laughed,
# Nearest to only: not, neither, exactly, just, never, especially, emmy, you,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to while: although, when, though, after, before, but, if, including,
# Nearest to zero: five, four, six, seven, eight, two, three, nine,
# Nearest to so: thus, too, then, therefore, zapu, duels, when, after,
# Nearest to to: must, should, could, can, will, would, affleck, may,
# Nearest to have: had, has, were, include, are, having, be, tend,
# Nearest to called: referred, named, characterized, used, known, magen, considered, motors,
# Nearest to war: arrows, campaign, anatomy, lms, succeeded, imagine, munitions, wars,
# Nearest to will: would, can, must, could, should, may, might, cannot,
# Nearest to use: materia, reduction, purpose, because, demand, fit, bulfinch, way,
# Nearest to not: never, only, nor, normally, still, now, always, actually,
# Nearest to no: any, little, microbial, holbein, fatima, stroustrup, watchmen, apps,
# Nearest to some: many, several, these, any, various, their, all, certain,
# Nearest to also: still, now, sometimes, often, never, generally, actually, usually,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
#CBOW is a technique in which we predicct the center based on other words 
#help taken from https://github.com/rndbrtrnd/udacity-deep-learning/blob/master/5_word2vec.ipynb

data_index = 0

def generate_batch(batch_size,bag_window):
  global data_index
  span = 2* bag_window + 1
  batch = np.ndarray(shape=(batch_size,span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  #we have removed the #of skips as  it is irrelevant in this case 
  #as the center word is not fixed 
  for i in range(batch_size):
    #getting a value for a deque is difficult
    buffer_list = list(buffer)
    labels[i,0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    #iterate to the next consecutive word
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1,2,3]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4,bag_window = bag_window)
    print('\nwith bag_window = %d' % (bag_window))
    print('    batch:', [[reverse_dictionary[i] for i in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']
#
# with bag_window = 3
#     batch: [['anarchism', 'originated', 'as', 'term', 'of', 'abuse'], ['originated', 'as', 'a', 'of', 'abuse', 'first'], ['as', 'a', 'term', 'abuse', 'first', 'used'], ['a', 'term', 'of', 'first', 'used', 'against']]
#     labels: ['a', 'term', 'of', 'abuse']

# %%
#generating more/big data
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 3 # How many words to consider left and right.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
    #as we are suming over all embeddings for context
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embed,1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.934804
# Nearest to about: cabot, melos, behaved, bite, rde, tique, gaseous, gcc,
# Nearest to system: capacity, broadly, saguinus, lumped, endorses, platters, circling, firewall,
# Nearest to was: polos, betray, sadness, lesser, vanes, ebirah, danville, lemons,
# Nearest to their: censor, later, illuminism, tintin, hot, syrian, lol, nir,
# Nearest to of: kao, dorm, microcomputers, abdali, defections, saban, lewiston, rain,
# Nearest to UNK: affirmative, cns, nigger, votive, melts, scary, paralleling, biola,
# Nearest to which: mourning, galatians, arrests, portsmouth, suggestion, retells, tumors, hath,
# Nearest to s: dee, pirin, distract, phoenicians, identifiable, ashland, generating, northumbrian,
# Nearest to or: purana, term, anaheim, breastfeeding, lofty, pontiff, penalized, leaped,
# Nearest to six: ishtar, unmodified, lithium, yapese, observables, indistinguishable, hairless, nongovernmental,
# Nearest to an: vomiting, symbolise, stative, poetess, sylia, traditionalists, attribute, unbiased,
# Nearest to other: watts, palmyra, sio, hoplites, correlates, ludo, checklist, shuster,
# Nearest to war: pinning, baud, lite, fabled, humoral, kohl, mpls, newcomers,
# Nearest to all: biomass, planetfall, suffragan, fetuses, deficit, phonological, bukovina, encodes,
# Nearest to see: incorporeal, sibling, ire, emission, unfit, understandings, bilingual, august,
# Nearest to time: gauthier, visualisation, soothe, rightmost, bodhisattva, blogs, arch, anal,
# Average loss at step 2000: 12.724958
# Average loss at step 4000: 7.527420
# Average loss at step 6000: 10.356826
# Average loss at step 8000: 5.715400
# Average loss at step 10000: 5.211789
# Nearest to about: legalized, fedora, wala, morte, galaxy, musical, executable, behaved,
# Nearest to system: angra, ibiblio, firewall, notated, heaviest, patient, bae, dymaxion,
# Nearest to was: were, is, had, are, tract, became, anubis, prized,
# Nearest to their: its, his, lunch, defector, corrupt, the, artemis, any,
# Nearest to of: under, harlequin, subspecies, devils, drew, weiser, leaked, exceeds,
# Nearest to UNK: ferris, sevilla, beaton, byrds, quadrants, lucasarts, pranks, injections,
# Nearest to which: this, michaux, that, handful, tobruk, cohn, benchmark, who,
# Nearest to s: cookery, concerned, epicureanism, buenos, her, protector, zhou, adair,
# Nearest to or: manatees, lordship, crazed, capo, inspirational, duplicate, whim, smitten,
# Nearest to six: seven, dj, nine, cosmopolitan, loyal, minerva, lavender, xof,
# Nearest to an: a, the, another, overseer, denatured, auden, aerodynamically, sleeves,
# Nearest to other: killing, league, bit, k, immigration, stadium, complex, pmid,
# Nearest to war: live, calamity, tradesmen, forces, washing, hippocampus, confusion, henze,
# Nearest to all: these, romanov, happens, sympathizers, skaters, some, suspicions, intercepts,
# Nearest to see: reginae, lada, dianne, vardar, ros, hickman, sited, jia,
# Nearest to time: point, least, rida, interwar, nadezhda, year, abductions, story,
# Average loss at step 12000: 4.581934
# Average loss at step 14000: 4.396248
# Average loss at step 16000: 4.514505
# Average loss at step 18000: 4.362798
# Average loss at step 20000: 4.141489
# Nearest to about: terry, colosseum, main, saturation, rotting, galaxy, happier, cosimo,
# Nearest to system: systems, notated, entre, foundation, cherbourg, rival, fugitive, chong,
# Nearest to was: is, were, became, are, has, had, does, being,
# Nearest to their: its, his, her, the, your, cheng, defector, vomiting,
# Nearest to of: khagan, includes, perplexed, unmanned, whomever, like, among, repubblica,
# Nearest to UNK: bert, leahy, easiest, peter, huguenot, melanesia, hamlet, along,
# Nearest to which: that, who, this, usually, biot, what, yeomen, whose,
# Nearest to s: his, lanterns, orchards, untrue, sarin, occ, terceira, tutte,
# Nearest to or: and, dey, codename, demilitarized, flown, notoriously, terrific, stationary,
# Nearest to six: four, seven, five, eight, armistice, three, profited, oktoberfest,
# Nearest to an: the, a, any, another, healthcare, this, boats, spoil,
# Nearest to other: various, catalan, music, several, different, gana, cholera, social,
# Nearest to war: reflux, reply, poul, zooming, cons, zapatistas, grid, sites,
# Nearest to all: various, untso, tourists, many, horseshoes, regular, albarn, alphabets,
# Nearest to see: lada, abbeys, asylum, fibres, ambients, known, baez, ink,
# Nearest to time: least, point, end, screwed, damaging, analogue, level, period,
# Average loss at step 22000: 4.665961
# Average loss at step 24000: 4.735702
# Average loss at step 26000: 4.530759
# Average loss at step 28000: 4.431193
# Average loss at step 30000: 4.063982
# Nearest to about: over, trichomes, main, pinstripes, stimulant, cesium, after, how,
# Nearest to system: systems, steward, talladega, spo, lough, overlooks, company, accomplishes,
# Nearest to was: is, were, became, are, had, makes, remains, becomes,
# Nearest to their: up, advertisements, immigration, separate, grapefruit, stein, krak, mario,
# Nearest to of: in, following, throughout, during, under, repubblica, circulating, gravitating,
# Nearest to UNK: de, mediator, gottfried, replies, und, resolutely, sola, reproduction,
# Nearest to which: that, this, what, biot, born, although, who, whose,
# Nearest to s: their, sarin, defun, real, slashed, whose, specialising, argo,
# Nearest to or: and, avraham, iqs, nne, demilitarized, willy, nootka, laughed,
# Nearest to six: eight, five, four, three, nine, bitumen, item, multiplied,
# Nearest to an: immigration, another, terrestrial, spider, advertisements, any, truffaut, lyrical,
# Nearest to other: different, various, some, many, several, wakko, fari, these,
# Nearest to war: movement, wars, amphisbaena, kumar, hatchback, stat, atoms, troubles,
# Nearest to all: many, some, various, each, every, other, different, both,
# Nearest to see: sited, references, cloistered, universalis, madhava, albigensians, except, gyeonggi,
# Nearest to time: least, mishandling, end, interwar, match, information, konami, battle,
# Average loss at step 32000: 3.759936
# Average loss at step 34000: 4.194539
# Average loss at step 36000: 4.466977
# Average loss at step 38000: 4.479938
# Average loss at step 40000: 4.340662
# Nearest to about: trichomes, proudhon, amelia, gleaned, quetzalcoatl, spontaneity, fuji, himmler,
# Nearest to system: systems, program, sense, angra, company, gallon, backstreet, immaterial,
# Nearest to was: is, were, became, are, remains, being, had, becomes,
# Nearest to their: his, its, her, your, any, my, ho, the,
# Nearest to of: in, coolest, throughout, during, includes, weiser, sdk, putatively,
# Nearest to UNK: bushy, liebig, erika, gasp, chloride, colonialism, luiz, star,
# Nearest to which: that, whose, when, biot, heather, swami, wifi, debit,
# Nearest to s: and, the, his, ante, deadlock, chairs, fencers, fascinated,
# Nearest to or: and, ante, jug, becomes, flown, brugge, philippine, educating,
# Nearest to six: eight, seven, five, four, three, one, artworks, choke,
# Nearest to an: another, any, a, sprawl, the, rahilly, vitro, reverberation,
# Nearest to other: various, these, rather, all, biota, were, nissan, moonraker,
# Nearest to war: wars, islamic, troubles, distract, salicylate, rivaled, circumvented, simulate,
# Nearest to all: many, several, various, other, some, lined, these, both,
# Nearest to see: except, replicas, known, caver, includes, codasyl, antiretroviral, natchez,
# Nearest to time: least, end, period, sense, received, ccg, interwar, newspeak,
# Average loss at step 42000: 4.147849
# Average loss at step 44000: 4.021636
# Average loss at step 46000: 3.865763
# Average loss at step 48000: 3.949356
# Average loss at step 50000: 3.994941
# Nearest to about: main, around, trichomes, detailed, tata, designating, poitou, nutrient,
# Nearest to system: systems, routes, mis, metre, representation, cardinal, digits, bus,
# Nearest to was: is, were, became, remains, are, being, becomes, makes,
# Nearest to their: his, its, her, my, the, our, your, ebro,
# Nearest to of: neoplatonist, following, in, biloxi, throughout, whereas, tubules, landry,
# Nearest to UNK: kenneth, foray, starring, leahy, peter, jr, hereditary, minaret,
# Nearest to which: that, this, who, what, whose, rosenthal, where, crosstown,
# Nearest to s: his, pared, our, my, whose, est, isbn, cryopreserved,
# Nearest to or: and, prescient, wynn, abstractions, like, hopelessly, characterise, galton,
# Nearest to six: eight, five, four, seven, jacob, assoc, unannounced, greyhound,
# Nearest to an: another, any, rahilly, a, reverberation, the, ellesmere, spoil,
# Nearest to other: rather, various, smaller, several, biota, certain, many, charitable,
# Nearest to war: wars, iterated, transcribed, rivaled, troubles, taiwan, briggs, fostering,
# Nearest to all: competencies, lists, these, forth, muslims, aurelianus, downplay, necker,
# Nearest to see: called, ink, hackett, natchez, sited, renovations, replicas, imprints,
# Nearest to time: least, times, point, temperature, months, period, reason, investing,
# Average loss at step 52000: 3.913096
# Average loss at step 54000: 3.869819
# Average loss at step 56000: 3.932237
# Average loss at step 58000: 4.057647
# Average loss at step 60000: 3.729138
# Nearest to about: on, around, gestures, enthusiastically, over, upon, because, trichomes,
# Nearest to system: idea, systems, form, archipelago, function, game, believer, motilal,
# Nearest to was: is, were, remains, became, becomes, had, are, has,
# Nearest to their: its, his, her, our, the, your, whose, staub,
# Nearest to of: gaku, bell, cardiff, adware, eras, officers, polarization, towards,
# Nearest to UNK: beekeepers, char, degrading, anybody, thurston, giordano, disconnected, beryllium,
# Nearest to which: that, when, this, who, where, whose, what, located,
# Nearest to s: his, whose, isbn, pared, the, dakuten, galindo, deadlock,
# Nearest to or: and, hamsters, than, though, orlogsflag, etc, traverse, gory,
# Nearest to six: cardiff, gaku, eras, medieval, deseret, grade, jim, bell,
# Nearest to an: another, a, rahilly, the, each, any, no, irrelevent,
# Nearest to other: rather, larger, smaller, wakko, different, various, more, multiple,
# Nearest to war: wars, coup, medieval, reign, dylan, converse, weekly, empress,
# Nearest to all: certain, some, these, many, various, several, ten, altenberg,
# Nearest to see: hackett, sited, slide, radios, known, sip, represent, indecisive,
# Nearest to time: point, distance, months, beginning, end, audience, period, moment,
# Average loss at step 62000: 3.609321
# Average loss at step 64000: 3.667552
# Average loss at step 66000: 3.525753
# Average loss at step 68000: 4.584931
# Average loss at step 70000: 3.806491
# Nearest to about: gestures, enthusiastically, main, brummell, mithraeum, peritoneum, related, over,
# Nearest to system: systems, concubine, howard, subjectivism, flanks, disillusioned, team, nene,
# Nearest to was: is, were, remains, became, becomes, are, makes, remained,
# Nearest to their: its, his, your, our, my, midshipman, varying, her,
# Nearest to of: for, biloxi, in, following, including, argentinean, same, licenced,
# Nearest to UNK: moles, scarring, zant, brasil, coleco, calvinism, nn, klang,
# Nearest to which: that, whose, who, this, biot, shovel, when, actually,
# Nearest to s: his, its, her, lamia, whose, antitrust, pared, sarin,
# Nearest to or: and, schrader, but, polyurethane, rale, bullying, anni, proxy,
# Nearest to six: eight, five, four, seven, backpacker, udo, unforgiven, affiliate,
# Nearest to an: another, a, every, any, the, sprawl, rahilly, this,
# Nearest to other: various, certain, different, individual, nonnegative, smaller, rather, larger,
# Nearest to war: troubles, slovene, imbalance, wars, themed, monotone, aromas, follower,
# Nearest to all: many, some, several, timbuktu, certain, altenberg, cobbler, both,
# Nearest to see: aer, includes, known, included, pickling, nhra, dynamics, canids,
# Nearest to time: least, period, audience, distance, level, look, stage, scruggs,
# Average loss at step 72000: 3.470809
# Average loss at step 74000: 3.667162
# Average loss at step 76000: 3.634588
# Average loss at step 78000: 3.483156
# Average loss at step 80000: 3.398490
# Nearest to about: gestures, enthusiastically, why, over, main, regarding, mycological, hegelians,
# Nearest to system: systems, axons, ombudsman, branch, idea, constitution, swf, version,
# Nearest to was: is, were, becomes, are, became, remains, had, makes,
# Nearest to their: its, his, our, your, my, her, the, whose,
# Nearest to of: following, in, represents, licenced, neoplatonist, behind, biloxi, throughout,
# Nearest to UNK: fred, aka, vocalized, indoctrination, carlos, troilus, droughts, chico,
# Nearest to which: that, where, this, whose, what, currently, usually, often,
# Nearest to s: his, whose, pared, its, unaccustomed, their, dakuten, rad,
# Nearest to or: and, than, but, devoured, macrobiotics, bartholomew, streaks, traverse,
# Nearest to six: five, four, three, seven, eight, bumblebee, gilmore, aristocrats,
# Nearest to an: another, this, a, rahilly, the, every, sprawl, reverberation,
# Nearest to other: various, certain, rather, fewer, wakko, different, many, multiple,
# Nearest to war: wars, troubles, revolution, monotone, kumar, stay, imbalance, cup,
# Nearest to all: many, various, several, certain, ten, every, some, any,
# Nearest to see: known, corvinus, pickling, gg, uses, eg, eudes, applies,
# Nearest to time: least, beginning, period, age, point, moment, end, conclusion,
# Average loss at step 82000: 3.407022
# Average loss at step 84000: 3.426674
# Average loss at step 86000: 3.374071
# Average loss at step 88000: 3.288915
# Average loss at step 90000: 3.471817
# Nearest to about: over, gestures, why, enthusiastically, around, jolley, telegraphy, customize,
# Nearest to system: systems, version, axons, jamaicans, uploading, network, lovingly, framework,
# Nearest to was: is, were, became, are, remains, had, becomes, makes,
# Nearest to their: its, his, your, whose, her, s, my, our,
# Nearest to of: following, behind, biloxi, repubblica, coolest, within, throughout, for,
# Nearest to UNK: marduk, curlers, embarks, richard, reversing, avatars, horace, john,
# Nearest to which: that, this, who, when, whose, normally, where, what,
# Nearest to s: their, whose, nach, his, isbn, tempus, hn, jeep,
# Nearest to or: and, but, than, kristeva, twain, earrings, although, andover,
# Nearest to six: three, four, eight, seven, five, correction, bis, ahimelech,
# Nearest to an: another, any, a, every, the, syncopation, rahilly, sporadic,
# Nearest to other: these, those, various, rather, certain, different, fewer, valet,
# Nearest to war: wars, revolution, troubles, par, phase, harmonization, rest, monotone,
# Nearest to all: various, certain, sublimation, some, these, every, most, torrent,
# Nearest to see: contains, applies, but, allows, refers, known, gyeonggi, called,
# Nearest to time: norm, conscripts, review, intermediate, mv, tale, sign, denied,
# Average loss at step 92000: 3.352226
# Average loss at step 94000: 3.280806
# Average loss at step 96000: 2.873959
# Average loss at step 98000: 3.097422
# Average loss at step 100000: 3.270379
# Nearest to about: over, called, around, telling, dispelled, despite, gleaned, gestures,
# Nearest to system: systems, nation, concept, rdenas, uploading, attorney, idea, jamaicans,
# Nearest to was: is, became, were, remains, are, becomes, had, remained,
# Nearest to their: its, his, her, our, my, your, the, s,
# Nearest to of: following, throughout, coolest, for, represents, biloxi, include, from,
# Nearest to UNK: waging, di, hippie, vocalized, receptive, l, koans, prof,
# Nearest to which: that, where, whom, what, this, who, kyrie, although,
# Nearest to s: his, whose, her, their, joseph, its, waikato, my,
# Nearest to or: gaku, adware, factional, deseret, mvs, checker, icon, intermediate,
# Nearest to six: eight, five, four, seven, three, nine, two, arable,
# Nearest to an: another, a, any, every, this, the, thoth, rahilly,
# Nearest to other: different, certain, various, fewer, more, multiple, these, numerous,
# Nearest to war: wars, revolution, morocco, invasion, irreconcilable, liberties, confusion, curfew,
# Nearest to all: some, many, certain, several, these, various, hundreds, numerous,
# Nearest to see: include, known, foreigners, refers, contains, eg, woke, refer,
# Nearest to time: point, meeting, period, times, moment, least, height, conclusion,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
